# %%
import pandas as pd
import numpy as np

df = pd.read_csv(r"C:\Users\ncled\code\SavvyCoders\Capstone\anxiety_dataset.csv")

# %%
print(df.columns)
# Out:
# Index(['Age', 'Gender', 'Occupation', 'Sleep Hours',
#        'Physical Activity (hrs/week)', 'Caffeine Intake (mg/day)',
#        'Alcohol Consumption (drinks/week)', 'Smoking',
#        'Family History of Anxiety', 'Stress Level (1-10)', 'Heart Rate (bpm)',
#        'Breathing Rate (breaths/min)', 'Sweating Level (1-5)', 'Dizziness',
#        'Rx', 'Therapy Sessions (per month)', 'Recent Major Life Event',
#        'Diet Quality (1-10)', 'Anxiety Level (1-10)'],
#       dtype='object')

# %%
new_df = df.dropna()
print(new_df.tail(10))
print(new_df.head(10))
# Out:
#        Age  Gender Occupation  Sleep Hours  Physical Activity (hrs/week)  \
# 10990   34   Other    Teacher          8.0                           3.0
# 10991   25    Male    Student          8.1                           2.4
# 10992   36  Female      Other          8.1                           3.8
# 10993   40   Other     Artist          8.2                           2.5
# 10994   30   Other    Athlete          8.3                           2.8
# 10995   39    Male    Student          8.3                           3.3
# 10996   40    Male    Student          8.5                           6.1
# 10997   53    Male    Student          8.7                           4.8
# 10998   19    Male   Musician          9.2                           3.7
# 10999   51    Male   Musician          9.9                           6.9
#
#        Caffeine Intake (mg/day)  Alcohol Consumption (drinks/week) Smoking  \
# 10990                       183                                  0      No
# ...

# %%
new_df_sorted = new_df.sort_values(by='Anxiety Level (1-10)', ascending=False)

# %%
print(new_df_sorted.tail(10))
print(new_df_sorted.head(10))
# Out:
#        Age  Gender  Occupation  Sleep Hours  Physical Activity (hrs/week)  \
# 10983   52    Male     Athlete          7.7                           3.1
# 10984   23  Female    Musician          7.7                           1.0
# 10963   52  Female     Teacher          6.8                           1.4
# 10964   51  Female     Teacher          6.9                           3.8
# 10965   26    Male   Scientist          6.9                           2.7
# 10966   56    Male  Freelancer          7.0                           6.4
# 10967   30  Female     Athlete          7.1                           5.8
# 10968   58   Other        Chef          7.1                           1.1
# 10969   20   Other       Nurse          7.1                           1.7
# 10970   34  Female      Artist          7.2                           3.5
#
#        Caffeine Intake (mg/day)  Alcohol Consumption (drinks/week) Smoking  \
# 10983                       153                                  0      No
# ...

# %%
new_df_sorted.to_csv(r'C:\Users\ncled\code\SavvyCoders\Capstone\anxiety_dataset_cleaned with drops.csv')
